# %% [markdown]
# <a href="https://colab.research.google.com/github/microsoft/qlib/blob/main/examples/workflow_by_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Copyright (c) Microsoft Corporation.
#  Licensed under the MIT License.

# %%
import sys, site
from pathlib import Path

################################# NOTE #################################
#  Please be aware that if colab installs the latest numpy and pyqlib  #
#  in this cell, users should RESTART the runtime in order to run the  #
#  following cells successfully.                                       #
########################################################################

try:
    import qlib
except ImportError:
    # install qlib
    ! pip install --upgrade numpy
    ! pip install pyqlib
    if "google.colab" in sys.modules:
        # The Google colab environment is a little outdated. We have to downgrade the pyyaml to make it compatible with other packages
        ! pip install pyyaml==5.4.1
    # reload
    site.main()

scripts_dir = Path.cwd().parent.joinpath("scripts")
if not scripts_dir.joinpath("get_data.py").exists():
    # download get_data.py script
    scripts_dir = Path("~/tmp/qlib_code/scripts").expanduser().resolve()
    scripts_dir.mkdir(parents=True, exist_ok=True)
    import requests

    with requests.get("https://raw.githubusercontent.com/microsoft/qlib/main/scripts/get_data.py", timeout=10) as resp:
        with open(scripts_dir.joinpath("get_data.py"), "wb") as fp:
            fp.write(resp.content)

# %%
import qlib
import pandas as pd
from qlib.constant import REG_CN
from qlib.utils import exists_qlib_data, init_instance_by_config
from qlib.workflow import R
from qlib.workflow.record_temp import SignalRecord, PortAnaRecord
from qlib.utils import flatten_dict

# %%
# use default data
# NOTE: need to download data from remote: python scripts/get_data.py qlib_data_cn --target_dir ~/.qlib/qlib_data/cn_data
provider_uri = "~/.qlib/qlib_data/cn_data"  # target_dir
if not exists_qlib_data(provider_uri):
    print(f"Qlib data is not found in {provider_uri}")
    sys.path.append(str(scripts_dir))
    from get_data import GetData

    GetData().qlib_data(target_dir=provider_uri, region=REG_CN)
qlib.init(provider_uri=provider_uri, region=REG_CN)
# Out:
# [9154:MainThread](2025-07-04 09:30:56,126) INFO - qlib.Initialization - [config.py:420] - default_conf: client.
# [9154:MainThread](2025-07-04 09:30:56,128) INFO - qlib.Initialization - [__init__.py:74] - qlib successfully initialized based on client settings.
# [9154:MainThread](2025-07-04 09:30:56,129) INFO - qlib.Initialization - [__init__.py:76] - data_path={'__DEFAULT_FREQ': PosixPath('/home/alvin/.qlib/qlib_data/cn_data')}

# %%
market = "csi300"
benchmark = "SH000300"

# %% [markdown]
# # train model

# %%
###################################
# train model
###################################
data_handler_config = {
    "start_time": "2008-01-01",
    "end_time": "2020-08-01",
    "fit_start_time": "2008-01-01",
    "fit_end_time": "2014-12-31",
    "instruments": market,
}

task = {
    "model": {
        "class": "LGBModel",
        "module_path": "qlib.contrib.model.gbdt",
        "kwargs": {
            "loss": "mse",
            "colsample_bytree": 0.8879,
            "learning_rate": 0.0421,
            "subsample": 0.8789,
            "lambda_l1": 205.6999,
            "lambda_l2": 580.9768,
            "max_depth": 8,
            "num_leaves": 210,
            "num_threads": 20,
        },
    },
    "dataset": {
        "class": "DatasetH",
        "module_path": "qlib.data.dataset",
        "kwargs": {
            "handler": {
                "class": "Alpha158",
                "module_path": "qlib.contrib.data.handler",
                "kwargs": data_handler_config,
            },
            "segments": {
                "train": ("2008-01-01", "2014-12-31"),
                "valid": ("2015-01-01", "2016-12-31"),
                "test": ("2017-01-01", "2020-08-01"),
            },
        },
    },
}

# model initialization
model = init_instance_by_config(task["model"])
dataset = init_instance_by_config(task["dataset"])

# start exp to train model
with R.start(experiment_name="train_model"):
    R.log_params(**flatten_dict(task))
    model.fit(dataset)
    R.save_objects(trained_model=model)
    rid = R.get_recorder().id
# Out:
# ModuleNotFoundError. CatBoostModel are skipped. (optional: maybe installing CatBoostModel can fix it.)
# ModuleNotFoundError. XGBModel is skipped(optional: maybe installing xgboost can fix it).
# [9154:MainThread](2025-07-04 09:31:22,123) INFO - qlib.timer - [log.py:127] - Time cost: 16.538s | Loading data Done
# [9154:MainThread](2025-07-04 09:31:22,625) INFO - qlib.timer - [log.py:127] - Time cost: 0.124s | DropnaLabel Done
# [9154:MainThread](2025-07-04 09:31:24,793) INFO - qlib.timer - [log.py:127] - Time cost: 2.167s | CSZScoreNorm Done
# [9154:MainThread](2025-07-04 09:31:24,795) INFO - qlib.timer - [log.py:127] - Time cost: 2.671s | fit & process data Done
# [9154:MainThread](2025-07-04 09:31:24,796) INFO - qlib.timer - [log.py:127] - Time cost: 19.211s | Init data Done
# [9154:MainThread](2025-07-04 09:31:24,801) WARNING - qlib.workflow - [expm.py:231] - No valid experiment found. Create a new experiment with name train_model.
# [9154:MainThread](2025-07-04 09:31:24,803) INFO - qlib.workflow - [exp.py:258] - Experiment 769099961555968432 starts running ...
# [9154:MainThread](2025-07-04 09:31:24,889) INFO - qlib.workflow - [recorder.py:345] - Recorder 245dd2d51c634d45968376938ef43d9e starts running under Experiment 769099961555968432 ...
# Training until validation scores don't improve for 50 rounds
# [20]	train's l2: 0.990585	valid's l2: 0.994309
# [40]	train's l2: 0.986931	valid's l2: 0.993693
# [60]	train's l2: 0.984352	valid's l2: 0.99349
# [80]	train's l2: 0.982281	valid's l2: 0.993418
# [100]	train's l2: 0.980478	valid's l2: 0.99334
# [120]	train's l2: 0.978685	valid's l2: 0.99328
# [140]	train's l2: 0.976958	valid's l2: 0.993318
# [160]	train's l2: 0.975324	valid's l2: 0.993362
# [9154:MainThread](2025-07-04 09:31:29,916) INFO - qlib.timer - [log.py:127] - Time cost: 0.057s | waiting `async_log` Done
# Early stopping, best iteration is:
# [121]	train's l2: 0.978594	valid's l2: 0.993276

# %% [markdown]
# # prediction, backtest & analysis

# %%
###################################
# prediction, backtest & analysis
###################################
port_analysis_config = {
    "executor": {
        "class": "SimulatorExecutor",
        "module_path": "qlib.backtest.executor",
        "kwargs": {
            "time_per_step": "day",
            "generate_portfolio_metrics": True,
        },
    },
    "strategy": {
        "class": "TopkDropoutStrategy",
        "module_path": "qlib.contrib.strategy.signal_strategy",
        "kwargs": {
            "model": model,
            "dataset": dataset,
            "topk": 50,
            "n_drop": 5,
        },
    },
    "backtest": {
        "start_time": "2017-01-01",
        "end_time": "2020-08-01",
        "account": 100000000,
        "benchmark": benchmark,
        "exchange_kwargs": {
            "freq": "day",
            "limit_threshold": 0.095,
            "deal_price": "close",
            "open_cost": 0.0005,
            "close_cost": 0.0015,
            "min_cost": 5,
        },
    },
}

# backtest and analysis
with R.start(experiment_name="backtest_analysis"):
    recorder = R.get_recorder(recorder_id=rid, experiment_name="train_model")
    model = recorder.load_object("trained_model")

    # prediction
    recorder = R.get_recorder()
    ba_rid = recorder.id
    sr = SignalRecord(model, dataset, recorder)
    sr.generate()

    # backtest & analysis
    par = PortAnaRecord(recorder, port_analysis_config, "day")
    par.generate()
# Out:
# [9154:MainThread](2025-07-04 09:31:43,337) WARNING - qlib.workflow - [expm.py:231] - No valid experiment found. Create a new experiment with name backtest_analysis.
# [9154:MainThread](2025-07-04 09:31:43,341) INFO - qlib.workflow - [exp.py:258] - Experiment 248626785957230443 starts running ...
# [9154:MainThread](2025-07-04 09:31:43,349) INFO - qlib.workflow - [recorder.py:345] - Recorder 45d9f453974d4c21b45d63cc7b571360 starts running under Experiment 248626785957230443 ...
# [9154:MainThread](2025-07-04 09:31:43,908) INFO - qlib.workflow - [record_temp.py:198] - Signal record 'pred.pkl' has been saved as the artifact of the Experiment 248626785957230443
# [9154:MainThread](2025-07-04 09:31:43,932) INFO - qlib.backtest caller - [__init__.py:93] - Create new exchange
# 'The following are prediction results of the LGBModel model.'
#                           score
# datetime   instrument
# 2017-01-03 SH600000   -0.039814
#            SH600008   -0.002331
#            SH600009    0.035470
#            SH600010   -0.014474
#            SH600015   -0.141234
# [9154:MainThread](2025-07-04 09:31:45,928) WARNING - qlib.online operator - [exchange.py:219] - $close field data contains nan.
# [9154:MainThread](2025-07-04 09:31:45,930) WARNING - qlib.online operator - [exchange.py:219] - $close field data contains nan.
# [9154:MainThread](2025-07-04 09:31:45,934) WARNING - qlib.online operator - [exchange.py:226] - factor.day.bin file not exists or factor contains `nan`. Order using adjusted_price.
# [9154:MainThread](2025-07-04 09:31:45,935) WARNING - qlib.online operator - [exchange.py:228] - trade unit 100 is not supported in adjusted_price mode.
# [9154:MainThread](2025-07-04 09:31:56,861) WARNING - qlib.data - [data.py:665] - load calendar error: freq=day, future=True; return current calendar!
# [9154:MainThread](2025-07-04 09:31:56,864) WARNING - qlib.data - [data.py:668] - You can get future calendar by referring to the following document: https://github.com/microsoft/qlib/blob/main/scripts/data_collector/contrib/README.md
# [9154:MainThread](2025-07-04 09:31:56,876) WARNING - qlib.BaseExecutor - [executor.py:121] - `common_infra` is not set for <qlib.backtest.executor.SimulatorExecutor object at 0x734035229f10>
# backtest loop:   0%|          | 0/871 [00:00<?, ?it/s]
# /home/alvin/miniconda3/envs/rl-fund/lib/python3.8/site-packages/qlib/utils/index_data.py:492: RuntimeWarning: Mean of empty slice
#   return np.nanmean(self.data)
# [9154:MainThread](2025-07-04 09:32:02,984) INFO - qlib.workflow - [record_temp.py:515] - Portfolio analysis record 'port_analysis_1day.pkl' has been saved as the artifact of the Experiment 248626785957230443
# [9154:MainThread](2025-07-04 09:32:02,989) INFO - qlib.workflow - [record_temp.py:540] - Indicator analysis record 'indicator_analysis_1day.pkl' has been saved as the artifact of the Experiment 248626785957230443
# 'The following are analysis results of benchmark return(1day).'
#                        risk
# mean               0.000477
# std                0.012295
# annualized_return  0.113561
# information_ratio  0.598699
# max_drawdown      -0.370479
# 'The following are analysis results of the excess return without cost(1day).'
#                        risk
# mean               0.000718
# std                0.005754
# annualized_return  0.170936
# information_ratio  1.925803
# max_drawdown      -0.068613
# 'The following are analysis results of the excess return with cost(1day).'
#                        risk
# mean               0.000522
# std                0.005752
# annualized_return  0.124330
# information_ratio  1.401210
# max_drawdown      -0.078963
# 'The following are analysis results of indicators(1day).'
#      value
# ffr    1.0
# pa     0.0
# pos    0.0
# [9154:MainThread](2025-07-04 09:32:03,358) INFO - qlib.timer - [log.py:127] - Time cost: 0.000s | waiting `async_log` Done

# %% [markdown]
# # analyze graphs

# %%
from qlib.contrib.report import analysis_model, analysis_position
from qlib.data import D

recorder = R.get_recorder(recorder_id=ba_rid, experiment_name="backtest_analysis")
print(recorder)
pred_df = recorder.load_object("pred.pkl")
report_normal_df = recorder.load_object("portfolio_analysis/report_normal_1day.pkl")
positions = recorder.load_object("portfolio_analysis/positions_normal_1day.pkl")
analysis_df = recorder.load_object("portfolio_analysis/port_analysis_1day.pkl")

# %% [markdown]
# ## analysis position

# %% [markdown]
# ### report

# %%
analysis_position.report_graph(report_normal_df)

# %% [markdown]
# ### risk analysis

# %%
analysis_position.risk_analysis_graph(analysis_df, report_normal_df)

# %% [markdown]
# ## analysis model

# %%
label_df = dataset.prepare("test", col_set="label")
label_df.columns = ["label"]

# %% [markdown]
# ### score IC

# %%
pred_label = pd.concat([label_df, pred_df], axis=1, sort=True).reindex(label_df.index)
analysis_position.score_ic_graph(pred_label)

# %% [markdown]
# ### model performance

# %%
analysis_model.model_performance_graph(pred_label)
